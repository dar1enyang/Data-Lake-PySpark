# %%
import configparser
from datetime import datetime
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format
from pyspark.sql import functions as F
from pyspark.sql import types as T
from schema import *

config = configparser.ConfigParser()
config.read('dl.cfg')
# Out:
# ['dl.cfg']

# %%
from schema import *

# %%
os.environ['AWS_ACCESS_KEY_ID']     = config.get("AWS", 'AWS_ACCESS_KEY_ID')
os.environ['AWS_SECRET_ACCESS_KEY'] = config.get("AWS", 'AWS_SECRET_ACCESS_KEY')

# %%
def create_spark_session():
    spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()
    return spark

# %%
spark = create_spark_session()
input_data = "s3a://udacity-dend/"
output_data = ""

# %%
logPath = 's3a://udacity-dend/log_data/2018/11/2018-11-12-events.json'
songPath = 's3a://udacity-dend/song_data/A/B/C/TRABCEI128F424C983.json'

# %%
df_log = spark.read.json(logPath)

# %%
df_song = spark.read.json(songPath)

# %%
df_song.head()
# Out:
# Row(artist_id='ARJIE2Y1187B994AB7', artist_latitude=None, artist_location='', artist_longitude=None, artist_name='Line Renaud', duration=152.92036, num_songs=1, song_id='SOUPIRU12A6D4FA1E1', title='Der Kleine Dompfaff', year=0)

# %% [markdown]
#     # extract columns to create songs table
#     songs_table =
#
#     # write songs table to parquet files partitioned by year and artist
#     songs_table
#
#     # extract columns to create artists table
#     artists_table =
#
#     # write artists table to parquet files
#     artists_table

# %%
df_song.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)

# %%
# artist table
artist_id = "artist_id"
name = "artist_name"
location = "artist_location"
latitude = "artist_latitude"
longitude = "artist_longitude"

# %%
# song table
song_id = "song_id"
title = "title"
artist_id = "artist_id"
year = "year"
duration = "duration"

# %%
df_artistTable = df_song.select(artist_id, name, location, latitude, longitude)
df_artistTable.toPandas()
# Out:
#             artist_id  artist_name artist_location artist_latitude  \
# 0  ARJIE2Y1187B994AB7  Line Renaud                            None
#
#   artist_longitude
# 0             None

# %%
df_songTable = df_song.select(song_id, title, artist_id, year, duration)
df_songTable.toPandas()
# Out:
#               song_id                title           artist_id  year  \
# 0  SOUPIRU12A6D4FA1E1  Der Kleine Dompfaff  ARJIE2Y1187B994AB7     0
#
#     duration
# 0  152.92036

# %%
# user table
user_id = "userId"
first_name = "firstName"
last_name = "lastName"
gender = "gender"
level = "level"

# %%
# time table
start_time = "ts"
hour = "hour"
day = "day"
week = "week"
month = "month"
year = "year"
weekday = "weekday"

# %%
df_log.limit(5).toPandas()["page"]
# Out:
# 0        Home
# 1    NextSong
# 2    NextSong
# 3    NextSong
# 4        Home
# Name: page, dtype: object

# %%
get_timestamp = F.udf(lambda x: datetime.fromtimestamp( (x/1000.0) ), T.TimestampType()) 
get_hour = F.udf(lambda x: x.hour, T.IntegerType()) 
get_day = F.udf(lambda x: x.day, T.IntegerType()) 
get_week = F.udf(lambda x: x.isocalendar()[1], T.IntegerType()) 
get_month = F.udf(lambda x: x.month, T.IntegerType()) 
get_year = F.udf(lambda x: x.year, T.IntegerType()) 
get_weekday = F.udf(lambda x: x.weekday(), T.IntegerType())

# %%
df_log = df_log.withColumn("timestamp", get_timestamp(df_log.ts))
df_log = df_log.withColumn("hour", get_hour(df_log.timestamp))
df_log = df_log.withColumn("day", get_day(df_log.timestamp))
df_log = df_log.withColumn("week", get_week(df_log.timestamp))
df_log = df_log.withColumn("month", get_month(df_log.timestamp))
df_log = df_log.withColumn("year", get_year(df_log.timestamp))
df_log = df_log.withColumn("weekday", get_weekday(df_log.timestamp))
df_log.limit(5).toPandas()
# Out:
#                                               artist       auth   firstName  \
# 0                                               None  Logged In     Celeste
# 1                                           Pavement  Logged In      Sylvie
# 2  Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                         Gary Allan  Logged In     Celeste
# 4                                               None  Logged In  Jacqueline
#
#   gender  itemInSession  lastName     length level  \
# 0      F              0  Williams        NaN  free
# 1      F              0      Cruz   99.16036  free
# 2      F              1  Williams  277.15873  free
# 3      F              2  Williams  211.22567  free
# 4      F              0     Lynch        NaN  paid
#
#                                        location method   ...     \
# 0                             Klamath Falls, OR    GET   ...
# 1  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT   ...
# 2                             Klamath Falls, OR    PUT   ...
# 3                             Klamath Falls, OR    PUT   ...
# 4             Atlanta-Sandy Springs-Roswell, GA    GET   ...
#
#               ts                                          userAgent  userId  \
# 0  1541990217796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 1  1541990258796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      10
# 2  1541990264796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 3  1541990541796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 4  1541990714796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      29
#
#                 timestamp  hour  day week month  year  weekday
# 0 2018-11-12 02:36:57.796     2   12   46    11  2018        0
# 1 2018-11-12 02:37:38.796     2   12   46    11  2018        0
# 2 2018-11-12 02:37:44.796     2   12   46    11  2018        0
# 3 2018-11-12 02:42:21.796     2   12   46    11  2018        0
# 4 2018-11-12 02:45:14.796     2   12   46    11  2018        0
#
# [5 rows x 25 columns]

# %%
df_log = df_log.filter(df_log["page"] == "NextSong")

# %%
df_log.limit(5).toPandas()["page"]
# Out:
# 0    NextSong
# 1    NextSong
# 2    NextSong
# 3    NextSong
# 4    NextSong
# Name: page, dtype: object

# %%
df_userTable = df_log.select(user_id, first_name, last_name, gender, level)
df_userTable.toPandas()
# Out:
#     userId   firstName   lastName gender level
# 0       10      Sylvie       Cruz      F  free
# 1       53     Celeste   Williams      F  free
# 2       53     Celeste   Williams      F  free
# 3       53     Celeste   Williams      F  free
# 4       29  Jacqueline      Lynch      F  paid
# 5       29  Jacqueline      Lynch      F  paid
# 6       29  Jacqueline      Lynch      F  paid
# 7       29  Jacqueline      Lynch      F  paid
# 8       29  Jacqueline      Lynch      F  paid
# 9       29  Jacqueline      Lynch      F  paid
# 10      68      Jordan  Rodriguez      F  free
# 11      94        Noah     Chavez      M  free
# 12     100       Adler    Barrera      M  free
# 13     100       Adler    Barrera      M  free
# 14     100       Adler    Barrera      M  free
# 15     100       Adler    Barrera      M  free
# 16      58       Emily     Benson      F  paid
# 17      58       Emily     Benson      F  paid
# 18      34      Evelin      Ayala      F  free
# 19      49       Chloe     Cuevas      F  free
# 20      86       Aiden       Hess      M  free
# 21      86       Aiden       Hess      M  free
# 22      86       Aiden       Hess      M  free
# 23      61      Samuel   Gonzalez      M  free
# 24      86       Aiden       Hess      M  free
# 25      86       Aiden       Hess      M  free
# 26      37      Jordan      Hicks      F  free
# 27      66       Kevin   Arellano      M  free
# 28      26        Ryan      Smith      M  free
# 29      26        Ryan      Smith      M  free
# ..     ...         ...        ...    ...   ...
# 136     58       Emily     Benson      F  paid
# 137     12      Austin    Rosales      M  free
# 138     58       Emily     Benson      F  paid
# 139     58       Emily     Benson      F  paid
# 140     12      Austin    Rosales      M  free
# 154  1542061796796    22   12    46     11  2018        0
# 155  1542062516796    22   12    46     11  2018        0
# 156  1542062706796    22   12    46     11  2018        0
# 157  1542062987796    22   12    46     11  2018        0
# 158  1542063232796    22   12    46     11  2018        0
# 159  1542063483796    22   12    46     11  2018        0
# 160  1542063919796    23   12    46     11  2018        0
# 161  1542064052796    23   12    46     11  2018        0
# 162  1542064212796    23   12    46     11  2018        0
# 163  1542064422796    23   12    46     11  2018        0
# 164  1542064659796    23   12    46     11  2018        0
# 165  1542064849796    23   12    46     11  2018        0
#
# [166 rows x 7 columns]

# %%
# songplay table
songplay_id = "songplayIndex"
start_time = "ts"
user_id = "userId"
level = "level"
song_id = "song_id"
artist_id = "artist_id"
session_id = "sessionId"
location = "artist_location"
user_agent = "userAgent"

# %%
df_log = df_log.withColumn("rowIndex", F.monotonically_increasing_id())

# %%
df_log.limit(5).toPandas()
# Out:
#                                               artist       auth   firstName  \
# 0                                           Pavement  Logged In      Sylvie
# 1  Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 2                                         Gary Allan  Logged In     Celeste
# 3                                 Charttraxx Karaoke  Logged In     Celeste
# 4                                     The Libertines  Logged In  Jacqueline
#
#   gender  itemInSession  lastName     length level  \
# 0      F              0      Cruz   99.16036  free
# 1      F              1  Williams  277.15873  free
# 2      F              2  Williams  211.22567  free
# 3      F              3  Williams  225.17506  free
# 4      F              1     Lynch  179.53914  paid
#
#                                        location method    ...     \
# 0  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT    ...
# 1                             Klamath Falls, OR    PUT    ...
# 2                             Klamath Falls, OR    PUT    ...
# 3                             Klamath Falls, OR    PUT    ...
# 4             Atlanta-Sandy Springs-Roswell, GA    PUT    ...
#
#                                            userAgent  userId  \
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      10
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...      53
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      29
#
#                 timestamp hour  day  week month  year weekday  rowIndex
# 0 2018-11-12 02:37:38.796    2   12    46    11  2018       0         0
# 1 2018-11-12 02:37:44.796    2   12    46    11  2018       0         1
# 2 2018-11-12 02:42:21.796    2   12    46    11  2018       0         2
# 3 2018-11-12 02:45:52.796    2   12    46    11  2018       0         3
# 4 2018-11-12 02:47:22.796    2   12    46    11  2018       0         4
#
# [5 rows x 26 columns]

# %% [markdown]
# # songplay

# %%
df_song2 = spark.read.json(songPath)

# %%
df_song2 = df_song2.select(song_id, artist_id, name, title)

# %%
df_song2.toPandas()
# Out:
#               song_id           artist_id  artist_name                title
# 0  SOUPIRU12A6D4FA1E1  ARJIE2Y1187B994AB7  Line Renaud  Der Kleine Dompfaff

# %%
# songplay table
songplay_id = "songplayIndex"
#start_time = "ts"
#user_id = "userId"
#level = "level"
#song_id = "song_id"
#artist_id = "artist_id"
session_id = "sessionId"
location = "location"
user_agent = "userAgent"
song = "song"
artist = "artist"

# %%
df_log2 = df_log2.select(start_time, user_id, level, session_id, location, user_agent, song, artist, year, month)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9de13413b720> in <module>()
# ----> 1 df_log2 = df_log2.select(start_time, user_id, level, session_id, location, user_agent, song, artist, year, month)
#
# NameError: name 'df_log2' is not defined

# %%
df_log2.limit(5).toPandas()

# %%
final = df_song2.join(df_log2, (df_song2.artist_name == df_log2.artist) & (df_song2.title == df_log2.song))

# %%
final.show()

# %%
final = final.select(start_time, user_id, level, song_id, artist_id, session_id, location, user_agent, year, month)

# %%
final.show()

# %%
final2 = final.withColumn("songplay_id", F.monotonically_increasing_id())

# %%
final2.show()
